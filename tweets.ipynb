# %%
import pandas as pd
import numpy as np
import os

# %%
data=pd.read_csv('tweets.csv.zip')

# %%
data.head()
# Out:
#    id keyword        location  \
# 0   0  ablaze             NaN
# 1   1  ablaze             NaN
# 2   2  ablaze   New York City
# 3   3  ablaze  Morgantown, WV
# 4   4  ablaze             NaN
#
#                                                 text  target
# 0  Communal violence in Bhainsa, Telangana. "Ston...       1
# 1  Telangana: Section 144 has been imposed in Bha...       1
# 2  Arsonist sets cars ablaze at dealership https:...       1
# 3  Arsonist sets cars ablaze at dealership https:...       1
# 4  "Lord Jesus, your love brings freedom and pard...       0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_19['id'].plot(kind='hist', bins=20, title='id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_20['target'].plot(kind='hist', bins=20, title='target')
# ...

# %%
data.describe()
# Out:
#                  id        target
# count  11370.000000  11370.000000
# mean    5684.500000      0.185928
# std     3282.380615      0.389066
# min        0.000000      0.000000
# 25%     2842.250000      0.000000
# 50%     5684.500000      0.000000
# 75%     8526.750000      0.000000
# max    11369.000000      1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_35['id'].plot(kind='hist', bins=20, title='id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_36['target'].plot(kind='hist', bins=20, title='target')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
data.isna()
# Out:
#           id  keyword  location   text  target
# 0      False    False      True  False   False
# 1      False    False      True  False   False
# 2      False    False     False  False   False
# 3      False    False     False  False   False
# 4      False    False      True  False   False
# ...      ...      ...       ...    ...     ...
# 11365  False    False     False  False   False
# 11366  False    False     False  False   False
# 11367  False    False     False  False   False
# 11368  False    False     False  False   False
# 11369  False    False      True  False   False
#
# [11370 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_40.groupby('location').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_40.groupby('location').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
import pandas as pd
def remove_hashtags(text):
    pattern = r"#\w+"
data= pd.DataFrame({"text": ["This is a tweet with #hashtag", "Another one with #anotherhashtag"]})
data["text"] = data["text"].apply(remove_hashtags)
print(data)
# Out:
#    text
# 0  None
# 1  None

# %%
# Out:
# Cleaned data saved to 'cleaned_dataset.csv.zip'

# %%
import pandas as pd
df = pd.read_csv('tweets.csv.zip')
df.columns = df.columns.str.replace('#', '', regex=False)
df = df.applymap(lambda x: x.replace('#', '') if isinstance(x, str) else x)
df.to_csv('cleaned_data_no_hash.csv.zip', index=False)
print("CSV file cleaned, and saved to 'cleaned_data_no_hash.csv.zip'")
# Out:
# <ipython-input-14-98837a2150cc>:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.replace('#', '') if isinstance(x, str) else x)
# CSV file cleaned, and saved to 'cleaned_data_no_hash.csv.zip'

# %%
import pandas as pd
l=pd.read_csv('cleaned_data_no_hash.csv.zip')
# Out:
#           id  keyword                 location  \
# 0          0   ablaze                      NaN
# 1          1   ablaze                      NaN
# 2          2   ablaze            New York City
# 3          3   ablaze           Morgantown, WV
# 4          4   ablaze                      NaN
# ...      ...      ...                      ...
# 11365  11365  wrecked  Blue State in a red sea
# 11366  11366  wrecked               arohaonces
# 11367  11367  wrecked                       🇵🇭
# 11368  11368  wrecked           auroraborealis
# 11369  11369  wrecked                      NaN
#
#                                                     text  target
# 0      Communal violence in Bhainsa, Telangana. "Ston...       1
# 1      Telangana: Section 144 has been imposed in Bha...       1
# 2      Arsonist sets cars ablaze at dealership https:...       1
# 3      Arsonist sets cars ablaze at dealership https:...       1
# 4      "Lord Jesus, your love brings freedom and pard...       0
# ...

# %% [markdown]
# # New Section

# %%
import pandas as pd
df = pd.read_csv('tweets.csv.zip')
df.columns = df.columns.str.replace('#', '', regex=False)
df = df.applymap(lambda x: x.replace('#', '') if isinstance(x, str) else x)
df.to_csv('cleaned_data_no_hash.csv.zip', index=False)
print("CSV file cleaned, and saved to 'cleaned_data_no_hash.csv.zip'")
# Out:
# <ipython-input-18-3604014d3323>:10: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.replace('#', '') if isinstance(x, str) else x)
# CSV file cleaned, and saved to 'cleaned_data_no_hash.csv.zip'

# %%
df.head(30)
# Out:
#     id keyword                                           location  \
# 0    0  ablaze                                                NaN
# 1    1  ablaze                                                NaN
# 2    2  ablaze                                      New York City
# 3    3  ablaze                                     Morgantown, WV
# 4    4  ablaze                                                NaN
# 5    5  ablaze                                                 OC
# 6    6  ablaze                                    London, England
# 7    7  ablaze                                             Bharat
# 8    8  ablaze                                       Accra, Ghana
# 9    9  ablaze                                          Searching
# 10  10  ablaze                                                NaN
# 11  11  ablaze                                                NaN
# 12  12  ablaze                                                NaN
# ...
